# %%
import pandas as pd
import os
print(os.listdir("C:\\Users\\HP\\Desktop\\Jupyter Projects\\Machine learning Projects\\Movie recomendation system collabrative filtering"))
# Out:
# ['.ipynb_checkpoints', 'genome-scores.csv', 'genome-tags.csv', 'links.csv', 'Movie recommender System Collaborative.ipynb', 'movies.csv', 'ratings.csv', 'README.txt', 'tags.csv', 'tmdb_5000_credits.csv', 'tmdb_5000_movies.csv', 'Untitled.ipynb']

# %%
# import movie data set and look at columns
movie = pd.read_csv("movies.csv")
movie.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
# what we need is that movie id and title
movie = movie.loc[:,["movieId","title"]]
movie.head(10)
# Out:
#    movieId                               title
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)

# %%
# import rating data and look at columsn
rating = pd.read_csv("ratings.csv")
rating.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
# what we need is that user id, movie id and rating
rating = rating.loc[:,["userId","movieId","rating"]]
rating.head(10)
# Out:
#    userId  movieId  rating
# 0       1      296     5.0
# 1       1      306     3.5
# 2       1      307     5.0
# 3       1      665     5.0
# 4       1      899     3.5
# 5       1     1088     4.0
# 6       1     1175     3.5
# 7       1     1217     3.5
# 8       1     1237     5.0
# 9       1     1250     4.0

# %%
# then merge movie and rating data
data = pd.merge(movie,rating)

# %%
# now lets look at our data 
data.head(10)
# Out:
#    movieId             title  userId  rating
# 0        1  Toy Story (1995)       2     3.5
# 1        1  Toy Story (1995)       3     4.0
# 2        1  Toy Story (1995)       4     3.0
# 3        1  Toy Story (1995)       5     4.0
# 4        1  Toy Story (1995)       8     4.0
# 5        1  Toy Story (1995)      10     3.5
# 6        1  Toy Story (1995)      12     4.0
# 7        1  Toy Story (1995)      13     4.0
# 8        1  Toy Story (1995)      18     3.0
# 9        1  Toy Story (1995)      26     3.0

# %%
data.shape
# Out:
# (25000095, 4)

# %%
data = data.iloc[:1000000,:]

# %%
# lets make a pivot table in order to make rows are users and columns are movies. And values are rating
pivot_table = data.pivot_table(index = ["userId"],columns = ["title"],values = "rating")
pivot_table.head(10)
# Out:
# title   Ace Ventura: When Nature Calls (1995)  Across the Sea of Time (1995)  \
# userId
# 2                                         NaN                            NaN
# 3                                         NaN                            NaN
# 4                                         NaN                            NaN
# 5                                         4.0                            NaN
# 7                                         NaN                            NaN
# 8                                         NaN                            NaN
# 9                                         NaN                            NaN
# 10                                        NaN                            NaN
# 12                                        NaN                            NaN
# 13                                        3.5                            NaN
#
# title   American President, The (1995)  Angela (1995)  \
# userId
# 2                                  NaN            NaN
# 3                                  NaN            NaN
# 4                                  NaN            NaN
# 5                                  NaN            NaN
# 7                                  NaN            NaN
# 8                                  3.0            NaN
# 9                                  NaN            NaN
# 10                                 NaN            NaN
# 12                                 NaN            NaN
# 13                                 NaN            NaN
#
# title   Angels and Insects (1995)  Anne Frank Remembered (1995)  \
# userId
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# 5                             NaN                           NaN
# 7                             NaN                           NaN
# 8                             NaN                           NaN
# 9                             NaN                           5.0
# 10                            NaN                           NaN
# 12                            NaN                           NaN
# 13                            NaN                           NaN
#
# title   Antonia's Line (Antonia) (1995)  Assassins (1995)  Babe (1995)  \
# userId
# 2                                   NaN               NaN          NaN
# 3                                   NaN               NaN          NaN
# 4                                   NaN               NaN          NaN
# 5                                   NaN               NaN          NaN
# 7                                   NaN               NaN          NaN
# 8                                   NaN               NaN          NaN
# 9                                   NaN               NaN          3.0
# 10                                  NaN               NaN          NaN
# 12                                  NaN               NaN          NaN
# 13                                  NaN               NaN          4.0
#
# title   Bad Boys (1995)  ...  Unforgettable (1996)  \
# userId                   ...
# 2                   NaN  ...                   NaN
# 3                   NaN  ...                   NaN
# 4                   NaN  ...                   NaN
# 5                   NaN  ...                   NaN
# 7                   NaN  ...                   NaN
# 8                   5.0  ...                   2.0
# 9                   NaN  ...                   NaN
# 10                  NaN  ...                   NaN
# 12                  2.5  ...                   NaN
# 13                  NaN  ...                   NaN
#
# title   Up Close and Personal (1996)  Usual Suspects, The (1995)  \
# userId
# 2                                NaN                         NaN
# 3                                NaN                         5.0
# 4                                NaN                         NaN
# 5                                NaN                         5.0
# 7                                NaN                         NaN
# 8                                NaN                         4.0
# 9                                NaN                         NaN
# 10                               NaN                         5.0
# 12                               3.0                         5.0
# 13                               NaN                         NaN
#
# title   Vampire in Brooklyn (1995)  Waiting to Exhale (1995)  \
# userId
# 2                              NaN                       NaN
# 3                              NaN                       NaN
# 4                              NaN                       NaN
# 5                              NaN                       NaN
# 7                              NaN                       NaN
# 8                              NaN                       NaN
# 9                              NaN                       NaN
# 10                             NaN                       NaN
# 12                             NaN                       NaN
# 13                             NaN                       NaN
#
# title   When Night Is Falling (1995)  \
# userId
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                               NaN
# 12                               NaN
# 13                               NaN
#
# title   White Balloon, The (Badkonake sefid) (1995)  White Squall (1996)  \
# userId
# 2                                               NaN                  NaN
# 3                                               NaN                  NaN
# 4                                               NaN                  NaN
# 5                                               NaN                  NaN
# 7                                               NaN                  NaN
# 8                                               NaN                  NaN
# 9                                               NaN                  NaN
# 10                                              NaN                  NaN
# 12                                              NaN                  NaN
# 13                                              NaN                  NaN
#
# title   Wings of Courage (1995)  Young Poisoner's Handbook, The (1995)
# userId
# 2                           NaN                                    NaN
# 3                           NaN                                    NaN
# 4                           NaN                                    NaN
# 5                           NaN                                    NaN
# 7                           NaN                                    NaN
# 8                           NaN                                    NaN
# 9                           NaN                                    NaN
# 10                          NaN                                    NaN
# 12                          NaN                                    NaN
# 13                          NaN                                    NaN
#
# [10 rows x 144 columns]

# %%
movie_watched = pivot_table["Bad Boys (1995)"]
similarity_with_other_movies = pivot_table.corrwith(movie_watched)  # find correlation between "Bad Boys (1995)" and other movies
similarity_with_other_movies = similarity_with_other_movies.sort_values(ascending=False)
similarity_with_other_movies.head()
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:2889: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# title
# Bad Boys (1995)                       1.000000
# Last Summer in the Hamptons (1995)    0.834058
# Two Bits (1995)                       0.697217
# Sonic Outlaws (1995)                  0.654654
# Guardian Angel (1994)                 0.587719
# dtype: float64
